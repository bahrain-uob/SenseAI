# %%
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker import get_execution_role, Session

session = Session()
role = get_execution_role()

sklearn_processor = SKLearnProcessor(
    framework_version="1.2-1",
    role=role,
    instance_type="ml.m5.4xlarge",
    instance_count=1,
    base_job_name="update-consignee-exit-fields",
    sagemaker_session=session
)

sklearn_processor.run(
    code="update_consignee_and_exit_fields.py",
    inputs=[
        ProcessingInput(
            source="s3://senseai-ml-results-bucket-hj20250426/cleaned/preprocessed_cleaned_final.csv",
            destination="/opt/ml/processing/input"
        )
    ],
    outputs=[
        ProcessingOutput(
            source="/opt/ml/processing/output",
            destination="s3://senseai-ml-results-bucket-hj20250426/cleaned/updated/"
        )
    ]
)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pydantic/_internal/_fields.py:172: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [06/02/25 08:14:56] INFO     Found credentials from IAM Role:                                   ]8;id=814017;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=429501;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# ...
