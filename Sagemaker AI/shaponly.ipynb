# %%
from sagemaker.processing import ScriptProcessor, ProcessingInput, ProcessingOutput
from sagemaker import get_execution_role, Session

session = Session()
role = get_execution_role()

script_processor = ScriptProcessor(
    image_uri="166555558375.dkr.ecr.me-south-1.amazonaws.com/shap-image",  # your custom ECR image
    command=["python3"],
    role=role,
    instance_count=1,
    instance_type="ml.m5.4xlarge",
    base_job_name="filter-shap-rows",
    sagemaker_session=session
)

script_processor.run(
    code="extract_shap_rows.py",  # your local script filename
    inputs=[
        ProcessingInput(
            source="s3://senseai-ml-results-bucket-hj20250426/inference-results/isolation-forest-batch-inference-hj-2025-06-03-01-12-27/anomaly_scores.csv",
            destination="/opt/ml/processing/input"
        )
    ],
    outputs=[
        ProcessingOutput(
            source="/opt/ml/processing/output",
            destination="s3://senseai-ml-results-bucket-hj20250426/filtered/shap_rows/"
        )
    ]
)
# Out:
# [06/03/25 03:59:18] INFO     Found credentials from IAM Role:                                   ]8;id=672630;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=837724;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
#                     INFO     Found credentials from IAM Role:                                   ]8;id=553479;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=572149;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# ...
